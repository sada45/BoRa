# %%
import numpy as np
import matplotlib.pyplot as plt

raw_datas = np.load("/home/user/RIOT-BoRa/sd_data.npy")
iq_signal = np.zeros(len(raw_datas), dtype=np.uint32)
# temp = raw_datas & 0xffff
temp = (raw_datas >>16) & 0xffff
plt.plot(temp[:])

# %%
iq_signal = np.load("/home/user/RIOT-BoRa/examples/BoRa_decoder_test/iq0.npy")
plt.figure()
# plt.plot(iq_signal.imag[:100])
# # plt.plot(iq_signal.imag[:])

# %%
for i in range(31, -1, -1):
    if (3328>>i)&1:
        print(i)
# Out:
# 11
# 10
# 8

# %%
iq_signal = np.load("/home/user/RIOT-BoRa/examples/BoRa_decoder_test/iq0.npy")
plt.figure()
plt.plot(iq_signal.real[:100000])
plt.plot(iq_signal.imag[:100000])

# %%
plt.figure()
plt.plot(iq_signal.real[:10000])
# plt.plot(iq_signal.imag[:])
